# %% [markdown]
# #Importing Dataset

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
# Out:
# In C:\ProgramData\Anaconda3\lib\site-packages\matplotlib\mpl-data\stylelib\_classic_test.mplstyle:
# The text.latex.preview rcparam was deprecated in Matplotlib 3.3 and will be removed two minor releases later.
# In C:\ProgramData\Anaconda3\lib\site-packages\matplotlib\mpl-data\stylelib\_classic_test.mplstyle:
# The mathtext.fallback_to_cm rcparam was deprecated in Matplotlib 3.3 and will be removed two minor releases later.
# In C:\ProgramData\Anaconda3\lib\site-packages\matplotlib\mpl-data\stylelib\_classic_test.mplstyle: Support for setting the 'mathtext.fallback_to_cm' rcParam is deprecated since 3.3 and will be removed two minor releases later; use 'mathtext.fallback : 'cm' instead.
# In C:\ProgramData\Anaconda3\lib\site-packages\matplotlib\mpl-data\stylelib\_classic_test.mplstyle:
# The validate_bool_maybe_none function was deprecated in Matplotlib 3.3 and will be removed two minor releases later.
# ...

# %% [markdown]
# Loading the dataset

# %%
car_df=pd.read_csv("C:\\Users\\User\\Desktop\\PGP-BA&DS\\8_Real_Project\\Car_Purchasing_Data.csv",encoding='ISO-8859-1')

# %%
car_df
# Out:
#        Customer Name                                    Customer e-mail  \
# 0      Martina Avila  cubilia.Curae.Phasellus@quisaccumsanconvallis.edu
# 1      Harlan Barnes                                eu.dolor@diam.co.uk
# 2    Naomi Rodriquez  vulputate.mauris.sagittis@ametconsectetueradip...
# 3    Jade Cunningham                            malesuada@dignissim.com
# 4       Cedric Leach     felis.ullamcorper.viverra@egetmollislectus.net
# ..               ...                                                ...
# 495           Walter                                ligula@Cumsociis.ca
# 496            Vanna                 Cum.sociis.natoque@Sedmolestie.edu
# 497            Pearl                      penatibus.et@massanonante.com
# 498             Nell                  Quisque.varius@arcuVivamussit.net
# 499            Marla                          Camaron.marla@hotmail.com
#
#           Country  Gender        Age  Annual Salary  Credit Card Debt  \
# ...

# %% [markdown]
# #Visualization of dataset

# %%
sns.pairplot(car_df)

# %% [markdown]
# #Defining dependent and independent variables

# %%
x=car_df.drop(['Customer Name','Country','Customer e-mail','Car Purchase Amount'],axis=1)

# %%
x
# Out:
#      Gender        Age  Annual Salary  Credit Card Debt    Net Worth
# 0         0  41.851720    62812.09301      11609.380910  238961.2505
# 1         0  40.870623    66646.89292       9572.957136  530973.9078
# 2         1  43.152897    53798.55112      11160.355060  638467.1773
# 3         1  58.271369    79370.03798      14426.164850  548599.0524
# 4         1  57.313749    59729.15130       5358.712177  560304.0671
# ..      ...        ...            ...               ...          ...
# 495       0  41.462515    71942.40291       6995.902524  541670.1016
# 496       1  37.642000    56039.49793      12301.456790  360419.0988
# 497       1  53.943497    68888.77805      10611.606860  764531.3203
# 498       1  59.160509    49811.99062      14013.034510  337826.6382
# 499       1  46.731152    61370.67766       9391.341628  462946.4924
#
# [500 rows x 5 columns]

# %%
y=car_df['Car Purchase Amount']

# %%
y
# Out:
# 0      35321.45877
# 1      45115.52566
# 2      42925.70921
# 3      67422.36313
# 4      55915.46248
#           ...
# 495    48901.44342
# 496    31491.41457
# 497    64147.28888
# 498    45442.15353
# 499    45107.22566
# Name: Car Purchase Amount, Length: 500, dtype: float64

# %%
x.shape
# Out:
# (500, 5)

# %%
y.shape
# Out:
# (500,)

# %% [markdown]
# #Feature Scaling

# %%
from sklearn.preprocessing import MinMaxScaler
scaler=MinMaxScaler()
x_scaled=scaler.fit_transform(x)

# %% [markdown]
# #Values are scaled between 0 to 1 and maximum and minimum values are found for the attributes

# %%
scaler.data_max_
# Out:
# array([1.e+00, 7.e+01, 1.e+05, 2.e+04, 1.e+06])

# %%
scaler.data_min_
# Out:
# array([    0.,    20., 20000.,   100., 20000.])

# %%
y=y.values.reshape(-1,1)

# %%
y
# Out:
# array([[35321.45877],
#        [45115.52566],
#        [42925.70921],
#        [67422.36313],
#        [55915.46248],
#        [56611.99784],
#        [28925.70549],
#        [47434.98265],
#        [48013.6141 ],
#        [38189.50601],
#        [59045.51309],
#        [42288.81046],
#        [28700.0334 ],
#        [49258.87571],
#        [49510.03356],
#        [53017.26723],
#        [41814.72067],
#        [43901.71244],
#        [44633.99241],
#        [54827.52403],
#        [51130.95379],
#        [43402.31525],
#        [47240.86004],
#        [46635.49432],
#        [45078.40193],
#        [44387.58412],
#        [37161.55393],
#        [49091.97185],
#        [58350.31809],
#        [43994.35972],
#        [17584.56963],
#        [44650.36073],
#        [66363.89316],
#        [53489.46214],
#        [39810.34817],
#        [51612.14311],
#        [38978.67458],
#        [10092.22509],
#        [35928.52404],
#        [54823.19221],
#        [45805.67186],
# ...

# %%
y.shape
# Out:
# (500, 1)

# %%
y_scaled=scaler.fit_transform(y)

# %%
y_scaled
# Out:
# array([[0.37072477],
#        [0.50866938],
#        [0.47782689],
#        [0.82285018],
#        [0.66078116],
#        [0.67059152],
#        [0.28064374],
#        [0.54133778],
#        [0.54948752],
#        [0.4111198 ],
#        [0.70486638],
#        [0.46885649],
#        [0.27746526],
#        [0.56702642],
#        [0.57056385],
#        [0.61996151],
#        [0.46217916],
#        [0.49157341],
#        [0.50188722],
#        [0.64545808],
#        [0.59339372],
#        [0.48453965],
#        [0.53860366],
#        [0.53007738],
#        [0.50814651],
#        [0.49841668],
#        [0.3966416 ],
#        [0.56467566],
#        [0.6950749 ],
#        [0.49287831],
#        [0.12090943],
#        [0.50211776],
#        [0.80794216],
#        [0.62661214],
#        [0.43394857],
#        [0.60017103],
#        [0.42223485],
#        [0.01538345],
#        [0.37927499],
#        [0.64539707],
#        [0.51838974],
#        [0.45869677],
#        [0.26804521],
# ...

# %% [markdown]
# #Training the model

# %%
from sklearn.model_selection import train_test_split

# %%
x_train,x_test,y_train,y_test=train_test_split(x_scaled,y_scaled,test_size=0.25)

# %%
x_train.shape
# Out:
# (375, 5)

# %%
x_test.shape
# Out:
# (125, 5)

# %% [markdown]
# #model training

# %%
import tensorflow.keras
from keras.models import Sequential
from keras.layers import Dense
model=Sequential()
model.add(Dense(50,input_dim=5,activation='relu'))
model.add(Dense(50,activation='relu'))
model.add(Dense(1,activation='linear'))

# %%
model.summary()
# Out:
# Model: "sequential"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# ...
# dense (Dense)                (None, 50)                300
# _________________________________________________________________
# dense_1 (Dense)              (None, 50)                2550
# _________________________________________________________________
# dense_2 (Dense)              (None, 1)                 51
# ...
# Total params: 2,901
# Trainable params: 2,901
# Non-trainable params: 0
# _________________________________________________________________

# %%
model.compile(optimizer='adam',loss='mean_squared_error',metrics=[tensorflow.keras.metrics.RootMeanSquaredError()])

# %%
epochs_hist=model.fit(x_train,y_train,epochs=100,batch_size=10,verbose=1,validation_split=0.2)
# Out:
# Epoch 1/100
# 30/30 [==============================] - 0s 4ms/step - loss: 3.5112e-04 - root_mean_squared_error: 0.0187 - val_loss: 1.0869e-04 - val_root_mean_squared_error: 0.0104
# Epoch 2/100
# 30/30 [==============================] - 0s 2ms/step - loss: 3.9825e-05 - root_mean_squared_error: 0.0063 - val_loss: 3.4719e-05 - val_root_mean_squared_error: 0.0059
# Epoch 3/100
# 30/30 [==============================] - 0s 2ms/step - loss: 1.1048e-05 - root_mean_squared_error: 0.0033 - val_loss: 3.5027e-05 - val_root_mean_squared_error: 0.0059
# Epoch 4/100
# 30/30 [==============================] - 0s 2ms/step - loss: 7.7788e-06 - root_mean_squared_error: 0.0028 - val_loss: 3.6040e-05 - val_root_mean_squared_error: 0.0060
# Epoch 5/100
# 30/30 [==============================] - 0s 7ms/step - loss: 5.9907e-06 - root_mean_squared_error: 0.0024 - val_loss: 3.0680e-05 - val_root_mean_squared_error: 0.0055
# Epoch 6/100
# ...

# %%
  model.compile(optimizer='adam',loss='mean_squared_error',metrics=[tensorflow.keras.metrics.RootMeanSquaredError()])

# %%
epochs_hist.history.keys()
# Out:
# dict_keys(['loss', 'root_mean_squared_error', 'val_loss', 'val_root_mean_squared_error'])

# %%
plt.plot(epochs_hist.history['loss'])
plt.plot(epochs_hist.history['val_loss'])
plt.title('Managing Loss')
plt.xlabel('Epoch')
plt.ylabel('Training and Validation_Loss')
plt.legend(['Training_Loss','Validation_Loss'])

# %%
x_test=np.array([[1,45,20000,10000,340000]])
y_pred=model.predict(x_test)

# %%
print("Expected Car Purchasing amount:",y_pred)
# Out:
# Expected Car Purchasing amount: [[152434.77]]
